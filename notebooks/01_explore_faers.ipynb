# %% [markdown]
# # FAERS Data Exploration
#
# This notebook explores the raw FAERS data structure, data quality, and basic statistics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import sys

# Add src to path
sys.path.insert(0, str(Path.cwd().parent / 'src'))

from src.data_ingest.load_faers import load_quarter_tables, combine_quarters
from src.data_ingest.dedupe_cases import dedupe_cases

# Set style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
