# %% [markdown]
# # Disproportionality Analysis
#
# This notebook performs ROR/PRR analysis to identify adverse event signals for longevity drugs.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import sys
import yaml

sys.path.insert(0, str(Path.cwd().parent / 'src'))

from src.models.disproportionality import run_disproportionality_analysis
from src.viz.volcano_plots import plot_volcano, plot_heatmap

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)
